# %%
import numpy as np

import tensorflow
import sciann as sn

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import scipy.io

import pandas as pd

import h5py
# Out:
# ---------------------- SCIANN 0.6.0.4 ----------------------
# For details, check out our review paper and the documentation at:
#  +  "https://arxiv.org/abs/2005.08803",
#  +  "https://www.sciann.com".

# %%
path = "NoCracK/config_file/Event0000/output.h5"

hf = h5py.File(path, 'r')

# %%
hf.keys()
# Out:
# <KeysViewHDF5 ['connectivity_ACOUSTIC', 'coordinates_ACOUSTIC', 'partitioning', 'volume']>

# %%
selected_ts = 70

loc = hf['coordinates_ACOUSTIC'][:].reshape(hf['coordinates_ACOUSTIC'][:].shape[0]*hf['coordinates_ACOUSTIC'][:].shape[1],2)

df = pd.DataFrame(columns={'X','Y'})
df['X'] = loc[:,0]
df['Y'] = loc[:,1]
df['X'] = np.round(df['X'],5)
df['Y'] = np.round(df['Y'],5)

values = hf['volume']['phi'][selected_ts,:,:,:25].reshape(2500*25)

df['PHI'] = values

df_clean = df.pivot_table(values='PHI',index='Y',columns='X')
df_clean.sort_index(axis=0,ascending=False,inplace=True)

# %%
plt.imshow(df_clean.values)

# %%
x = sn.Variable('x')
y = sn.Variable('y')
t = sn.Variable('t')

p = sn.Functional('p', [x, y, t], 8*[20], 'tanh')

# %%
vp = 1400
rho = 1200

c = np.sqrt(vp/rho)

# %%
p_xx = sn.diff(p, x, order=2)
p_yy = sn.diff(p, y, order=2)
p_tt = sn.diff(p, t, order=2)

L1 = p_xx + p_yy - 1/(c**2)*p_tt

# %%
# Data : 
x_data, y_data, t_data = np.meshgrid(
    np.linspace(0, 0.25, 101),
    np.linspace(0, 0.25, 101),
    np.linspace(0, 1e-4, 101)
    )

# %%
# Ricker source time function
def Ricker(t,f):
    """
    t = time interval
    f = center frequency
    """
    t0 = 2./f
    ricker_wavelet = (1 - 2 * (np.pi ** 2) * (f ** 2) * ((t - t0) ** 2))*np.exp(-(np.pi ** 2) * (f ** 2) * ((t - t0) ** 2))
    return ricker_wavelet

# %%
# Boxcar source time funciton
def Boxcar(t,f):
    t0 = 2./f
    boxcar_wavelet  = -8. * (t - t0) * f * (np.exp(-1.0 * (4*f) ** 2 * (t - t0) ** 2))
    return boxcar_wavelet

# %%
f = 1e5

t_in = np.linspace(0,1e-4,100)

fig, ax = plt.subplots(1,2, figsize=(8,4))
ax[0].plot(t_in,Boxcar(t_in,f))
ax[0].set_title('Boxcar')
ax[1].plot(t_in,Ricker(t_in,f))
ax[1].set_title('Ricker')
# Out:
# Text(0.5, 1.0, 'Ricker')

# %%
from sciann.utils.math import sign, exp
from numpy import pi

# %%
TOL = 0.001

# Initial conditions for p :
# p(t=0,x,y) = 0
C1 = (1-sign(t - TOL)) * (p) 

# Boundary conditions for p at the source location
# p(t,x=x_s,y=y_s) = source
t0 = 2./f
xs = 0.125
ys = 0.125

C2 = (1-sign(x - (xs+TOL) + y - (ys+TOL) )) * (p - (1 - 2 * (pi ** 2) * (f ** 2) * ((t - t0) ** 2))*exp(-(pi ** 2) * (f ** 2) * ((t - t0) ** 2)))

# %%
# Define the optimization model (set of inputs and constraints)
model = sn.SciModel(
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 8.5340e-18 - mul_2_loss: 3.0360e-06 - mul_6_loss: 0.0599
# Epoch 99/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 9.2746e-19 - mul_2_loss: 3.6418e-06 - mul_6_loss: 0.0598
# Epoch 100/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 5.0284e-18 - mul_2_loss: 3.1337e-06 - mul_6_loss: 0.0598
# Epoch 101/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 6.2096e-22 - mul_2_loss: 1.9488e-06 - mul_6_loss: 0.0598
# Epoch 102/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 2.6758e-17 - mul_2_loss: 3.5403e-06 - mul_6_loss: 0.0599
# Epoch 103/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 1.7148e-21 - mul_2_loss: 2.3863e-06 - mul_6_loss: 0.0598
# Epoch 104/200
# 1030301/1030301 [==============================] - 30s 29us/sample - loss: 0.0598 - sub_loss: 4.7085e-21 - mul_2_loss: 2.3179e-06 - mul_6_loss: 0.0599
# Epoch 105/200
# 1030301/1030301 [==============================] - 28s 27us/sample - loss: 0.0598 - sub_loss: 4.8152e-18 - mul_2_loss: 3.3394e-06 - mul_6_loss: 0.0598
# Epoch 106/200
# 1030301/1030301 [==============================] - 29s 28us/sample - loss: 0.0598 - sub_loss: 1.0330e-19 - mul_2_loss: 2.1396e-06 - mul_6_loss: 0.0599
# Epoch 107/200
# 1030301/1030301 [==============================] - 34s 33us/sample - loss: 0.0598 - sub_loss: 6.5922e-18 - mul_2_loss: 3.6177e-06 - mul_6_loss: 0.0599
# Epoch 108/200
#  444416/1030301 [===========>..................] - ETA: 20s - loss: 0.0594 - sub_loss: 8.2518e-24 - mul_2_loss: 2.0729e-06 - mul_6_loss: 0.0594

# %%
x_test, y_test, t_test = np.meshgrid(
    np.linspace(0, 0.25, 101),
    np.linspace(0, 0.25, 101),
    np.linspace(0, 1e-4, 101)
)
p_pred = p.eval(model, [x_test, y_test, t_test])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d41a9c3e9d4a> in <module>
#       4     np.linspace(0, 1e-4, 101)
#       5 )
# ----> 6 p_pred = p.eval(model, [x_test, y_test, t_test])
#
# NameError: name 'p' is not defined

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4),sharey=True)

cbar = plt.colorbar(ax[0].imshow(p_pred[:,:,99],extent=[-1, 1, -1, 1]),ax=ax[0])
cbar.set_label('Velocity (m/s)')
ax[0].set_xlabel('x (m)', fontsize=14)
ax[0].set_ylabel('y (m)', fontsize=14)

ax[0].tick_params(labelsize=10)
ax[0].set_title('Initial conditions for u', fontsize=14)

cbar = plt.colorbar(ax[1].imshow(p_pred[:,:,0],extent=[-1, 1, -1, 1]),ax=ax[1])
cbar.set_label('Velocity (m/s)')
ax[1].set_xlabel('x (m)', fontsize=14)

ax[1].tick_params(labelsize=10)
ax[1].set_title('Initial conditions for v', fontsize=14)
