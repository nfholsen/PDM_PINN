# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from model import *
from model_burger_pinn import *

from itertools import cycle
import scipy.io # To load the matrix
from pyDOE import lhs # For Latin Hypercube samplig method
import numpy as np

# %%
# Model name
model_name = 'burgers_1d_pinn.pt'

# CUDA support 
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
# # # Known labels dataset
class u_Dataset(Dataset):
    def __init__(self, inputs, outputs):
        super(Dataset, self).__init__()

        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return self.inputs.shape[0]
        
    def __getitem__(self, index):

        # X 
        X = self.inputs[index, :]

        y = self.outputs[index]
        return X, y

# # # Residuals dataset
class f_Dataset(Dataset):
    def __init__(self, inputs):
        super(Dataset, self).__init__()

        self.inputs = inputs

    def __len__(self):
        return self.inputs.shape[0]
        
    def __getitem__(self, index):

        # X 
        X = self.inputs[index, :]

        return X

# %%
# # # Parameters
nu = 0.01/np.pi
noise = 0.0        

N_u = 100
N_f = 10000

data = scipy.io.loadmat('burgers_shock.mat')

t = data['t'].flatten()[:,None]
x = data['x'].flatten()[:,None]
Exact = np.real(data['usol']).T

X, T = np.meshgrid(x,t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
u_star = Exact.flatten()[:,None]              

# Domain bounds
lb = X_star.min(0)
ub = X_star.max(0)    

# Initial conditions
xx1 = np.hstack((X[0:1,:].T, T[0:1,:].T))  # x = -1:1, t = 0
uu1 = Exact[0:1,:].T

# Boundary conditions
xx2 = np.hstack((X[:,0:1], T[:,0:1]))   # x = -1, t = 0:1
uu2 = Exact[:,0:1]

# Boundary conditions
xx3 = np.hstack((X[:,-1:], T[:,-1:])) # x = 1, t = 0:1
uu3 = Exact[:,-1:]

X_u_train = np.vstack([xx1, xx2, xx3])
u_train = np.vstack([uu1, uu2, uu3])

idx = np.random.choice(X_u_train.shape[0], N_u, replace=False)
X_u_train = X_u_train[idx, :]
u_train = u_train[idx,:]

X_f_train = lb + (ub-lb)*lhs(2, N_f)
X_f_train = np.vstack((X_f_train, X_u_train))

print('Collocations :',X_u_train.shape)
print('All residuals :',X_f_train.shape)
# Out:
# Collocations : (100, 2)
# All residuals : (10100, 2)

# %% [markdown]
# ## Train with : Adam

# %%
f_dataset = f_Dataset(X_f_train)
u_dataset = u_Dataset(X_u_train,u_train)

f_trainloader = DataLoader(f_dataset, batch_size=1010, shuffle=True, num_workers=0)
u_trainloader = DataLoader(u_dataset, batch_size=10, shuffle=True, num_workers=0)

# %%
dnn = Model(in_size=2,neurons_layer=[20,20,20,20,20,20],out_size=1)
dnn = dnn.to(device)

optimizer = torch.optim.Adam(dnn.parameters(), lr=1e-2)

net_u = Net_U(model=dnn)
net_f = Net_F(net_u=net_u,nu=nu)

pinn_loss = PINN_loss()

# %%
epoch = 2000

tot_loss = []
tot_loss_u = []
tot_loss_f = []

for i in range(epoch):
    dnn.train()

    epoch_loss = 0
    epoch_loss_u = 0
    epoch_loss_f = 0

    for (X_u, u),(X_f) in zip(cycle(u_trainloader), f_trainloader):

        x_u = torch.tensor(X_u[:, 0:1], requires_grad=True).float().to(device)
        t_u = torch.tensor(X_u[:, 1:2], requires_grad=True).float().to(device)

        u = torch.tensor(u, requires_grad=True).float().to(device)
        
        x_f = torch.tensor(X_f[:, 0:1], requires_grad=True).float().to(device)
        t_f = torch.tensor(X_f[:, 1:2], requires_grad=True).float().to(device)       

        optimizer.zero_grad()

        preds_u = net_u(x_u,t_u)
        preds_f = net_f(x_f,t_f)

        loss, loss_u, loss_f = pinn_loss(u,preds_u,preds_f)

        loss.backward()

        optimizer.step()

        # Add loss
        epoch_loss += loss.item()
        epoch_loss_u += loss_u.item()
        epoch_loss_f += loss_f.item()

    tot_loss.append(epoch_loss)
    tot_loss_u.append(epoch_loss_u)
    tot_loss_f.append(epoch_loss_f)

    if i % 100 == 0:
        print('Iter %d, Loss: %.3e, Loss_u: %.3e, Loss_f: %.3e' % (i,epoch_loss, epoch_loss_u, epoch_loss_f))
# Out:
# ipykernel_launcher:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ipykernel_launcher:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ipykernel_launcher:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ipykernel_launcher:21: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ipykernel_launcher:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Iter 0, Loss: 2.546e+00, Loss_u: 2.532e+00, Loss_f: 1.439e-02
# Iter 100, Loss: 2.470e-01, Loss_u: 1.473e-01, Loss_f: 9.964e-02
# Iter 200, Loss: 2.691e-01, Loss_u: 1.510e-01, Loss_f: 1.181e-01
# Iter 300, Loss: 1.512e-01, Loss_u: 5.065e-02, Loss_f: 1.005e-01
# Iter 400, Loss: 4.301e-01, Loss_u: 1.835e-01, Loss_f: 2.467e-01
# Iter 500, Loss: 1.631e-01, Loss_u: 8.059e-02, Loss_f: 8.254e-02
# Iter 600, Loss: 1.428e-01, Loss_u: 3.917e-02, Loss_f: 1.037e-01
# Iter 700, Loss: 1.603e-01, Loss_u: 3.501e-02, Loss_f: 1.252e-01
# Iter 800, Loss: 1.307e-01, Loss_u: 5.806e-02, Loss_f: 7.265e-02
# Iter 900, Loss: 2.356e-01, Loss_u: 6.781e-02, Loss_f: 1.678e-01
# Iter 1000, Loss: 9.258e-02, Loss_u: 5.874e-02, Loss_f: 3.383e-02
# Iter 1100, Loss: 5.779e-01, Loss_u: 3.139e-01, Loss_f: 2.640e-01
# Iter 1200, Loss: 3.628e-01, Loss_u: 1.887e-01, Loss_f: 1.742e-01
# Iter 1300, Loss: 3.027e-01, Loss_u: 1.138e-01, Loss_f: 1.889e-01
# Iter 1400, Loss: 2.308e-01, Loss_u: 7.215e-02, Loss_f: 1.586e-01
# Iter 1500, Loss: 4.462e-01, Loss_u: 2.574e-01, Loss_f: 1.888e-01
# Iter 1600, Loss: 3.014e-01, Loss_u: 1.157e-01, Loss_f: 1.857e-01
# Iter 1700, Loss: 4.733e-01, Loss_u: 2.933e-01, Loss_f: 1.800e-01
# Iter 1800, Loss: 4.763e-01, Loss_u: 3.067e-01, Loss_f: 1.695e-01
# Iter 1900, Loss: 1.124e-01, Loss_u: 5.192e-02, Loss_f: 6.045e-02

# %%
# Save model 
PATH = model_name

torch.save(dnn.state_dict(), PATH)

# %%
# Load model
PATH = "PINN/B_E50000_U100_F10000.pt"

model_test = Model(in_size=2,neurons_layer=[20,20,20,20,20,20],out_size=1)
model_test.load_state_dict(torch.load(PATH))
model_test.eval()
# Out:
# Model(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Linear(in_features=20, out_features=20, bias=True)
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Linear(in_features=20, out_features=20, bias=True)
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Linear(in_features=20, out_features=20, bias=True)
#   )
#   (out): Linear(in_features=20, out_features=1, bias=True)
#   (tanh): Tanh()
# )

# %%
# Predictions
net_u = Net_U(model=model_test)
net_f = Net_F(net_u=net_u,nu=nu)

x = torch.tensor(X_star[:, 0:1], requires_grad=True).float()
t = torch.tensor(X_star[:, 1:2], requires_grad=True).float()

u_preds = net_u(x, t)
f_preds = net_f(x, t)

u_preds = u_preds.detach().cpu().numpy()
f_preds = f_preds.detach().cpu().numpy()

# %%
# Compute Error
error_u = np.linalg.norm(u_star-u_preds,2)/np.linalg.norm(u_star,2)

print(error_u)
# Out:
# 0.003327926681578323

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
U_pred = griddata(X_star, u_preds.flatten(), (X, T), method='cubic')
U_star = griddata(X_star, u_star.flatten(), (X, T), method='cubic')
U_error = griddata(X_star, u_star.flatten()-u_preds.flatten(), (X, T), method='cubic')

# %%
def add_colorbar():
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.10)
    cbar = fig.colorbar(h, cax=cax)
    cbar.ax.tick_params(labelsize=15)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec

# %%
fig = plt.figure(figsize=(7, 7))
ax0 = fig.add_subplot(311)
ax1 = fig.add_subplot(312)
ax2 = fig.add_subplot(313)

h = ax0.imshow(U_star.T,extent=[0, 1, -1, 1], aspect='auto',cmap='rainbow')
ax0.set_title('True $u(t,x)$', fontsize = 20)

divider = make_axes_locatable(ax0)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=15) 

h = ax1.imshow(U_pred.T,extent=[0, 1, -1, 1], aspect='auto',cmap='rainbow')
ax1.set_title('Predicted $u(t,x)$', fontsize = 20)

divider = make_axes_locatable(ax1)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=15) 

h = ax2.imshow(U_error.T,extent=[0, 1, -1, 1], aspect='auto',cmap='rainbow')
ax2.set_title('Error $u(t,x)$', fontsize = 20)

divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=15) 

plt.tight_layout()

# %%
fig = plt.figure(figsize=(10,7))

gs = gridspec.GridSpec(2, 3)

ax = fig.add_subplot(gs[0, :])

h = ax.imshow(U_star.T,extent=[0, 1, -1, 1], aspect='auto',cmap='rainbow')
ax.plot(
    X_u_train[:,1], 
    X_u_train[:,0], 
    'kx', label = 'Data (%d points)' % (u_train.shape[0]), 
    markersize = 4,
    clip_on = False
)
divider = make_axes_locatable(ax0)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=15) 

ax0 = fig.add_subplot(gs[1, 0])
ax1 = fig.add_subplot(gs[1, 1])
ax2 = fig.add_subplot(gs[1, 2])

ax0.set_title('$t = 0.25$', fontsize = 15)
ax0.plot(data['x'].flatten()[:,None],Exact[25,:], 'b-', linewidth = 2, label = 'Exact')       
ax0.plot(data['x'].flatten()[:,None],U_pred[25,:], 'r--', linewidth = 2, label = 'Prediction')
ax0.axis('square')

ax1.set_title('$t = 0.50$', fontsize = 15)
ax1.plot(data['x'].flatten()[:,None],Exact[50,:], 'b-', linewidth = 2, label = 'Exact')       
ax1.plot(data['x'].flatten()[:,None],U_pred[50,:], 'r--', linewidth = 2, label = 'Prediction')
ax1.axis('square')

ax2.set_title('$t = 0.75$', fontsize = 15)
ax2.plot(data['x'].flatten()[:,None],Exact[75,:], 'b-', linewidth = 2, label = 'Exact')       
ax2.plot(data['x'].flatten()[:,None],U_pred[75,:], 'r--', linewidth = 2, label = 'Prediction')
ax2.axis('square')

line = np.linspace(data['x'].flatten()[:,None].min(), data['x'].flatten()[:,None].max(), 2)[:,None]
ax.plot(data['t'].flatten()[:,None][25]*np.ones((2,1)), line, 'w-', linewidth = 1)
ax.plot(data['t'].flatten()[:,None][50]*np.ones((2,1)), line, 'w-', linewidth = 1)
ax.plot(data['t'].flatten()[:,None][75]*np.ones((2,1)), line, 'w-', linewidth = 1)

for ax in [ax0,ax1,ax2]:
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(15)
    
    ax.set_xlabel('$x$')
    ax.set_ylabel('$u(t,x)$')
    ax.set_xlim([-1.1,1.1])
    ax.set_ylim([-1.1,1.1]) 

ax1.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.25), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)

plt.tight_layout()

# %%
# Analyis : PINN vs Data Driven

# # # Parameters
nu = 0.01/np.pi
noise = 0.0
N_u = 100   

data = scipy.io.loadmat('burgers_shock.mat')

t = data['t'].flatten()[:,None]
x = data['x'].flatten()[:,None]
Exact = np.real(data['usol']).T

X, T = np.meshgrid(x,t)

X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
u_star = Exact.flatten()[:,None]  

# Initial conditions
xx1 = np.hstack((X[0:1,:].T, T[0:1,:].T))  # x = -1:1, t = 0
uu1 = Exact[0:1,:].T

# Boundary conditions
xx2 = np.hstack((X[:,0:1], T[:,0:1]))   # x = -1, t = 0:1
uu2 = Exact[:,0:1]
xx3 = np.hstack((X[:,-1:], T[:,-1:])) # x = 1, t = 0:1
uu3 = Exact[:,-1:]

X_u_train = np.vstack([xx1, xx2, xx3])
u_train = np.vstack([uu1, uu2, uu3])

idx = np.random.choice(X_u_train.shape[0], N_u, replace=False) 
X_u_train = X_u_train[idx, :]
u_train = u_train[idx,:]

lb = X_star.min(0)
ub = X_star.max(0)

# Start for loop 
for N_f in [10,20,50,100,200,500,1000,2000,5000,10000]:

    # Clean Domain
    X_f_train = lb + (ub-lb)*lhs(2, N_f)
    X_f_train = np.vstack((X_f_train, X_u_train))

    print('Total training data',X_u_train.shape[0])
    print('Total residual data',X_f_train.shape[0])

    u_dataset = u_Dataset(X_u_train,u_train)
    f_dataset = f_Dataset(X_f_train)
    u_trainloader = DataLoader(u_dataset, batch_size=int(N_u/10), shuffle=True, num_workers=0)
    f_trainloader = DataLoader(f_dataset, batch_size=int(N_f/10), shuffle=True, num_workers=0)

    dnn = Model(in_size=2,neurons_layer=[20,20,20,20,20,20],out_size=1)
    dnn = dnn.to(device)

    optimizer = torch.optim.Adam(dnn.parameters(), lr=1e-2)

    net_u = Net_U(dnn=dnn)
    net_f = Net_F(net_u=net_u,nu=nu)
    
    pinn_loss = PINN_loss()

    epoch = 2000

    tot_loss = []
    tot_loss_u = []
    tot_loss_f = []

    for i in range(epoch):
        dnn.train()

        epoch_loss = 0
        epoch_loss_u = 0
        epoch_loss_f = 0

        for (X_u, u),(X_f) in zip(u_trainloader, f_trainloader):

            x_u = torch.tensor(X_u[:, 0:1], requires_grad=True).float().to(device)
            t_u = torch.tensor(X_u[:, 1:2], requires_grad=True).float().to(device)

            u = torch.tensor(u, requires_grad=True).float().to(device)
        
            x_f = torch.tensor(X_f[:, 0:1], requires_grad=True).float().to(device)
            t_f = torch.tensor(X_f[:, 1:2], requires_grad=True).float().to(device)       
            optimizer.zero_grad()

            preds_u = net_u(x_u,t_u)
            preds_f = net_f(x_f,t_f)

            loss, loss_u, loss_f = pinn_loss(u,preds_u,preds_f)

            loss.backward()

            optimizer.step()

            # Add loss
            epoch_loss += loss
            epoch_loss_u += loss_u
            epoch_loss_f += loss_f

        tot_loss.append(epoch_loss)
        tot_loss_u.append(epoch_loss_u)
        tot_loss_f.append(epoch_loss_f)

        if i % 100 == 0:
            print('Iter %d, Loss: %.3e, Loss_u: %.3e, Loss_f: %.3e' % (i,epoch_loss, epoch_loss_u, epoch_loss_f))
    
    PATH = f'burgers_1d_pinn_{N_f}.pt'
    torch.save(dnn.state_dict(), PATH)
# Out:
# Total training data 100
# Total residual data 110
# C:\Users\nilso\anaconda3\envs\TORCH\lib\site-packages\ipykernel_launcher.py:79: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\nilso\anaconda3\envs\TORCH\lib\site-packages\ipykernel_launcher.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\nilso\anaconda3\envs\TORCH\lib\site-packages\ipykernel_launcher.py:82: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\nilso\anaconda3\envs\TORCH\lib\site-packages\ipykernel_launcher.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\nilso\anaconda3\envs\TORCH\lib\site-packages\ipykernel_launcher.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Iter 0, Loss: 2.133e+00, Loss_u: 2.112e+00, Loss_f: 2.128e-02
# Iter 100, Loss: 1.646e+00, Loss_u: 1.646e+00, Loss_f: 3.881e-05
# Iter 200, Loss: 1.996e+00, Loss_u: 1.996e+00, Loss_f: 1.878e-07
# Iter 300, Loss: 1.945e+00, Loss_u: 1.945e+00, Loss_f: 8.440e-11
# Iter 400, Loss: 1.989e+00, Loss_u: 1.989e+00, Loss_f: 1.601e-09
# Iter 500, Loss: 1.954e+00, Loss_u: 1.954e+00, Loss_f: 4.255e-11
# Iter 600, Loss: 2.019e+00, Loss_u: 2.019e+00, Loss_f: 7.494e-07
# Iter 700, Loss: 2.078e+00, Loss_u: 2.078e+00, Loss_f: 1.634e-07
# Iter 800, Loss: 1.984e+00, Loss_u: 1.984e+00, Loss_f: 2.239e-09
# Iter 900, Loss: 2.252e+00, Loss_u: 2.252e+00, Loss_f: 2.001e-10
# Iter 1000, Loss: 2.326e+00, Loss_u: 2.326e+00, Loss_f: 4.327e-09
# Iter 1100, Loss: 1.948e+00, Loss_u: 1.948e+00, Loss_f: 1.417e-14
# Iter 1200, Loss: 1.947e+00, Loss_u: 1.947e+00, Loss_f: 2.470e-11
# Iter 1300, Loss: 1.951e+00, Loss_u: 1.951e+00, Loss_f: 7.101e-08
# Iter 1400, Loss: 2.315e+00, Loss_u: 2.315e+00, Loss_f: 1.588e-18
# Iter 1500, Loss: 2.050e+00, Loss_u: 2.050e+00, Loss_f: 5.573e-17
# Iter 1600, Loss: 2.437e+00, Loss_u: 2.437e+00, Loss_f: 4.861e-20
# Iter 1700, Loss: 2.508e+00, Loss_u: 2.508e+00, Loss_f: 4.093e-12
# Iter 1800, Loss: 2.454e+00, Loss_u: 2.454e+00, Loss_f: 2.087e-18
# Iter 1900, Loss: 2.463e+00, Loss_u: 2.463e+00, Loss_f: 2.439e-16
# Total training data 100
# Total residual data 120
# Iter 0, Loss: 2.491e+00, Loss_u: 2.479e+00, Loss_f: 1.255e-02
# Iter 100, Loss: 2.524e+00, Loss_u: 2.524e+00, Loss_f: 2.741e-06
# Iter 200, Loss: 2.422e+00, Loss_u: 2.422e+00, Loss_f: 4.959e-12
# Iter 300, Loss: 2.463e+00, Loss_u: 2.463e+00, Loss_f: 1.843e-09
# Iter 400, Loss: 2.431e+00, Loss_u: 2.431e+00, Loss_f: 3.351e-10
# Iter 500, Loss: 2.403e+00, Loss_u: 2.403e+00, Loss_f: 1.034e-10
# Iter 600, Loss: 2.398e+00, Loss_u: 2.398e+00, Loss_f: 3.433e-09
# Iter 700, Loss: 2.426e+00, Loss_u: 2.426e+00, Loss_f: 5.728e-11
# Iter 800, Loss: 2.674e+00, Loss_u: 2.674e+00, Loss_f: 4.360e-09
# Iter 900, Loss: 2.457e+00, Loss_u: 2.457e+00, Loss_f: 1.060e-13
# Iter 1000, Loss: 2.430e+00, Loss_u: 2.430e+00, Loss_f: 2.971e-09
# Iter 1100, Loss: 2.400e+00, Loss_u: 2.400e+00, Loss_f: 9.673e-06
# Iter 1200, Loss: 2.051e+00, Loss_u: 2.051e+00, Loss_f: 7.683e-06
# Iter 1300, Loss: 1.437e+00, Loss_u: 1.428e+00, Loss_f: 8.977e-03
# Iter 1400, Loss: 2.707e+00, Loss_u: 2.420e+00, Loss_f: 2.869e-01
# Iter 1500, Loss: 2.912e+00, Loss_u: 2.265e+00, Loss_f: 6.473e-01
# Iter 1600, Loss: 1.593e+02, Loss_u: 7.949e+01, Loss_f: 7.978e+01
# Iter 1700, Loss: 7.604e+01, Loss_u: 7.602e+01, Loss_f: 2.434e-02
# Iter 1800, Loss: 7.322e+01, Loss_u: 7.260e+01, Loss_f: 6.177e-01
# Iter 1900, Loss: 7.399e+01, Loss_u: 6.872e+01, Loss_f: 5.277e+00
# Total training data 100
# Total residual data 150
# Iter 0, Loss: 2.303e+00, Loss_u: 2.297e+00, Loss_f: 6.584e-03
# Iter 100, Loss: 2.291e+00, Loss_u: 2.289e+00, Loss_f: 2.383e-03
# Iter 200, Loss: 2.486e+00, Loss_u: 2.486e+00, Loss_f: 2.854e-08
# Iter 300, Loss: 2.445e+00, Loss_u: 2.445e+00, Loss_f: 5.913e-12
# Iter 400, Loss: 2.494e+00, Loss_u: 2.494e+00, Loss_f: 1.765e-08
# Iter 500, Loss: 2.416e+00, Loss_u: 2.416e+00, Loss_f: 7.424e-10
# Iter 600, Loss: 2.451e+00, Loss_u: 2.451e+00, Loss_f: 3.127e-15
# Iter 700, Loss: 2.400e+00, Loss_u: 2.400e+00, Loss_f: 9.970e-16
# Iter 800, Loss: 2.413e+00, Loss_u: 2.413e+00, Loss_f: 8.913e-17
# Iter 900, Loss: 2.543e+00, Loss_u: 2.543e+00, Loss_f: 3.508e-17
# Iter 1000, Loss: 2.451e+00, Loss_u: 2.451e+00, Loss_f: 4.714e-17
# Iter 1100, Loss: 2.483e+00, Loss_u: 2.483e+00, Loss_f: 4.253e-18
# Iter 1200, Loss: 2.650e+00, Loss_u: 2.650e+00, Loss_f: 1.188e-18
# Iter 1300, Loss: 2.812e+00, Loss_u: 2.812e+00, Loss_f: 2.538e-18
# Iter 1400, Loss: 2.614e+00, Loss_u: 2.614e+00, Loss_f: 1.368e-19
# Iter 1500, Loss: 2.551e+00, Loss_u: 2.551e+00, Loss_f: 1.176e-20
# Iter 1600, Loss: 2.520e+00, Loss_u: 2.520e+00, Loss_f: 2.333e-20
# Iter 1700, Loss: 2.519e+00, Loss_u: 2.519e+00, Loss_f: 1.553e-20
# Iter 1800, Loss: 2.663e+00, Loss_u: 2.663e+00, Loss_f: 2.019e-21
# Iter 1900, Loss: 2.444e+00, Loss_u: 2.444e+00, Loss_f: 1.443e-21
# Total training data 100
# Total residual data 200
# Iter 0, Loss: 2.512e+00, Loss_u: 2.477e+00, Loss_f: 3.453e-02
# Iter 100, Loss: 4.077e+00, Loss_u: 2.795e+00, Loss_f: 1.282e+00
# Iter 200, Loss: 2.831e+00, Loss_u: 2.610e+00, Loss_f: 2.213e-01
# Iter 300, Loss: 2.497e+00, Loss_u: 2.416e+00, Loss_f: 8.060e-02
# Iter 400, Loss: 2.509e+00, Loss_u: 2.259e+00, Loss_f: 2.503e-01
# Iter 500, Loss: 2.279e+00, Loss_u: 2.106e+00, Loss_f: 1.731e-01
# Iter 600, Loss: 2.068e+00, Loss_u: 1.907e+00, Loss_f: 1.608e-01
# Iter 700, Loss: 1.898e+00, Loss_u: 1.768e+00, Loss_f: 1.296e-01
# Iter 800, Loss: 1.785e+00, Loss_u: 1.707e+00, Loss_f: 7.849e-02
# Iter 900, Loss: 1.681e+00, Loss_u: 1.668e+00, Loss_f: 1.285e-02
# Iter 1000, Loss: 1.650e+00, Loss_u: 1.633e+00, Loss_f: 1.696e-02
# Iter 1100, Loss: 1.636e+00, Loss_u: 1.625e+00, Loss_f: 1.081e-02
# Iter 1200, Loss: 1.634e+00, Loss_u: 1.622e+00, Loss_f: 1.272e-02
# Iter 1300, Loss: 1.609e+00, Loss_u: 1.601e+00, Loss_f: 7.265e-03
# Iter 1400, Loss: 1.620e+00, Loss_u: 1.589e+00, Loss_f: 3.072e-02
# Iter 1500, Loss: 1.596e+00, Loss_u: 1.565e+00, Loss_f: 3.094e-02
# Iter 1600, Loss: 1.567e+00, Loss_u: 1.522e+00, Loss_f: 4.533e-02
# Iter 1700, Loss: 1.539e+00, Loss_u: 1.522e+00, Loss_f: 1.634e-02
# Iter 1800, Loss: 1.091e+01, Loss_u: 7.848e+00, Loss_f: 3.066e+00
# Iter 1900, Loss: 8.982e+00, Loss_u: 6.933e+00, Loss_f: 2.049e+00
# Total training data 100
# Total residual data 300
# Iter 0, Loss: 2.213e+00, Loss_u: 2.179e+00, Loss_f: 3.433e-02
# Iter 100, Loss: 1.707e+00, Loss_u: 1.429e+00, Loss_f: 2.789e-01
# Iter 200, Loss: 1.541e+00, Loss_u: 1.452e+00, Loss_f: 8.943e-02
# Iter 300, Loss: 3.019e+00, Loss_u: 2.863e+00, Loss_f: 1.563e-01
# Iter 400, Loss: 2.549e+00, Loss_u: 2.549e+00, Loss_f: 2.092e-10
# Iter 500, Loss: 2.558e+00, Loss_u: 2.558e+00, Loss_f: 1.428e-08
# Iter 600, Loss: 2.640e+00, Loss_u: 2.640e+00, Loss_f: 5.725e-10
# Iter 700, Loss: 2.411e+00, Loss_u: 2.411e+00, Loss_f: 2.922e-06
# Iter 800, Loss: 2.516e+00, Loss_u: 2.516e+00, Loss_f: 2.382e-10
# Iter 900, Loss: 2.593e+00, Loss_u: 2.593e+00, Loss_f: 2.135e-10
# Iter 1000, Loss: 2.439e+00, Loss_u: 2.439e+00, Loss_f: 1.103e-10
# Iter 1100, Loss: 2.764e+00, Loss_u: 2.764e+00, Loss_f: 2.855e-11
# Iter 1200, Loss: 2.593e+00, Loss_u: 2.593e+00, Loss_f: 1.104e-15
# Iter 1300, Loss: 2.545e+00, Loss_u: 2.545e+00, Loss_f: 3.657e-12
# Iter 1400, Loss: 2.530e+00, Loss_u: 2.530e+00, Loss_f: 4.203e-12
# Iter 1500, Loss: 2.424e+00, Loss_u: 2.424e+00, Loss_f: 3.042e-12
# Iter 1600, Loss: 2.512e+00, Loss_u: 2.512e+00, Loss_f: 8.144e-13
# Iter 1700, Loss: 2.435e+00, Loss_u: 2.435e+00, Loss_f: 3.790e-13
# Iter 1800, Loss: 2.470e+00, Loss_u: 2.470e+00, Loss_f: 3.992e-13
# Iter 1900, Loss: 2.513e+00, Loss_u: 2.513e+00, Loss_f: 2.409e-13
# Total training data 100
# Total residual data 600
# Iter 0, Loss: 2.277e+00, Loss_u: 2.265e+00, Loss_f: 1.177e-02
# Iter 100, Loss: 1.129e+00, Loss_u: 9.189e-01, Loss_f: 2.104e-01
# Iter 200, Loss: 1.109e+00, Loss_u: 1.003e+00, Loss_f: 1.065e-01
# Iter 300, Loss: 6.339e-01, Loss_u: 4.234e-01, Loss_f: 2.104e-01
# Iter 400, Loss: 2.528e+00, Loss_u: 2.528e+00, Loss_f: 1.421e-06
# Iter 500, Loss: 1.552e+00, Loss_u: 1.417e+00, Loss_f: 1.341e-01
# Iter 600, Loss: 2.480e+00, Loss_u: 2.480e+00, Loss_f: 2.804e-08
# Iter 700, Loss: 2.431e+00, Loss_u: 2.431e+00, Loss_f: 9.498e-07
# Iter 800, Loss: 2.581e+00, Loss_u: 2.581e+00, Loss_f: 2.724e-08
# Iter 900, Loss: 2.458e+00, Loss_u: 2.458e+00, Loss_f: 1.590e-06
# Iter 1000, Loss: 2.417e+00, Loss_u: 2.417e+00, Loss_f: 9.247e-07
# Iter 1100, Loss: 2.446e+00, Loss_u: 2.446e+00, Loss_f: 6.588e-07
# Iter 1200, Loss: 2.455e+00, Loss_u: 2.455e+00, Loss_f: 6.057e-07
# Iter 1300, Loss: 2.660e+00, Loss_u: 2.660e+00, Loss_f: 6.464e-07
# Iter 1400, Loss: 2.448e+00, Loss_u: 2.448e+00, Loss_f: 5.626e-07
# Iter 1500, Loss: 2.848e+00, Loss_u: 2.848e+00, Loss_f: 3.577e-07
# Iter 1600, Loss: 2.510e+00, Loss_u: 2.510e+00, Loss_f: 1.744e-07
# Iter 1700, Loss: 2.621e+00, Loss_u: 2.621e+00, Loss_f: 5.580e-07
# Iter 1800, Loss: 2.630e+00, Loss_u: 2.630e+00, Loss_f: 2.914e-07
# Iter 1900, Loss: 2.488e+00, Loss_u: 2.488e+00, Loss_f: 1.528e-07
# Total training data 100
# Total residual data 1100
# Iter 0, Loss: 2.282e+00, Loss_u: 2.244e+00, Loss_f: 3.841e-02
# Iter 100, Loss: 4.977e-01, Loss_u: 3.615e-01, Loss_f: 1.362e-01
# Iter 200, Loss: 7.512e-01, Loss_u: 5.790e-01, Loss_f: 1.722e-01
# Iter 300, Loss: 1.118e+00, Loss_u: 8.324e-01, Loss_f: 2.856e-01
# Iter 400, Loss: 1.472e+00, Loss_u: 1.442e+00, Loss_f: 3.001e-02
# Iter 500, Loss: 6.571e-01, Loss_u: 4.295e-01, Loss_f: 2.276e-01
# Iter 600, Loss: 1.492e+00, Loss_u: 1.260e+00, Loss_f: 2.325e-01
# Iter 700, Loss: 1.936e+00, Loss_u: 1.734e+00, Loss_f: 2.022e-01
# Iter 800, Loss: 1.177e+00, Loss_u: 1.019e+00, Loss_f: 1.579e-01
# Iter 900, Loss: 9.855e-01, Loss_u: 8.148e-01, Loss_f: 1.707e-01
# Iter 1000, Loss: 8.456e-01, Loss_u: 6.543e-01, Loss_f: 1.913e-01
# Iter 1100, Loss: 1.674e+00, Loss_u: 1.548e+00, Loss_f: 1.252e-01
# Iter 1200, Loss: 6.883e-01, Loss_u: 4.712e-01, Loss_f: 2.170e-01
# Iter 1300, Loss: 5.722e-01, Loss_u: 3.938e-01, Loss_f: 1.784e-01
# Iter 1400, Loss: 6.007e-01, Loss_u: 4.520e-01, Loss_f: 1.487e-01
# Iter 1500, Loss: 7.404e-01, Loss_u: 6.064e-01, Loss_f: 1.340e-01
# Iter 1600, Loss: 2.472e+00, Loss_u: 2.472e+00, Loss_f: 5.126e-11
# Iter 1700, Loss: 2.436e+00, Loss_u: 2.436e+00, Loss_f: 4.331e-11
# Iter 1800, Loss: 2.431e+00, Loss_u: 2.431e+00, Loss_f: 2.321e-11
# Iter 1900, Loss: 2.540e+00, Loss_u: 2.540e+00, Loss_f: 1.335e-11
# Total training data 100
# Total residual data 2100
# Iter 0, Loss: 2.729e+00, Loss_u: 2.724e+00, Loss_f: 5.040e-03
# Iter 100, Loss: 6.533e-01, Loss_u: 4.823e-01, Loss_f: 1.709e-01
# Iter 200, Loss: 5.602e-01, Loss_u: 3.590e-01, Loss_f: 2.012e-01
# Iter 300, Loss: 5.919e-01, Loss_u: 4.509e-01, Loss_f: 1.410e-01
# Iter 400, Loss: 6.805e-01, Loss_u: 4.769e-01, Loss_f: 2.036e-01
# Iter 500, Loss: 5.496e-01, Loss_u: 3.487e-01, Loss_f: 2.009e-01
# Iter 600, Loss: 6.156e-01, Loss_u: 4.084e-01, Loss_f: 2.072e-01
# Iter 700, Loss: 5.719e-01, Loss_u: 3.743e-01, Loss_f: 1.975e-01
# Iter 800, Loss: 6.201e-01, Loss_u: 4.435e-01, Loss_f: 1.766e-01
# Iter 900, Loss: 7.940e-01, Loss_u: 5.545e-01, Loss_f: 2.395e-01
# Iter 1000, Loss: 6.488e-01, Loss_u: 3.731e-01, Loss_f: 2.757e-01
# Iter 1100, Loss: 5.264e-01, Loss_u: 3.759e-01, Loss_f: 1.505e-01
# Iter 1200, Loss: 1.334e+00, Loss_u: 1.168e+00, Loss_f: 1.663e-01
# Iter 1300, Loss: 9.798e-01, Loss_u: 8.539e-01, Loss_f: 1.258e-01
# Iter 1400, Loss: 1.027e+00, Loss_u: 9.006e-01, Loss_f: 1.264e-01
# Iter 1500, Loss: 1.104e+00, Loss_u: 9.765e-01, Loss_f: 1.271e-01
# Iter 1600, Loss: 4.335e-01, Loss_u: 3.120e-01, Loss_f: 1.214e-01
# Iter 1700, Loss: 7.793e-01, Loss_u: 5.083e-01, Loss_f: 2.710e-01
# Iter 1800, Loss: 8.824e-01, Loss_u: 6.458e-01, Loss_f: 2.366e-01
# Iter 1900, Loss: 8.182e-01, Loss_u: 6.484e-01, Loss_f: 1.698e-01
# Total training data 100
# Total residual data 5100
# Iter 0, Loss: 2.193e+00, Loss_u: 2.184e+00, Loss_f: 8.810e-03
# Iter 100, Loss: 4.095e-01, Loss_u: 2.720e-01, Loss_f: 1.375e-01
# Iter 200, Loss: 5.363e-01, Loss_u: 3.469e-01, Loss_f: 1.895e-01
# Iter 300, Loss: 5.291e-01, Loss_u: 3.716e-01, Loss_f: 1.575e-01
# Iter 400, Loss: 4.058e-01, Loss_u: 2.615e-01, Loss_f: 1.443e-01
# Iter 500, Loss: 9.773e-01, Loss_u: 6.921e-01, Loss_f: 2.853e-01
# Iter 600, Loss: 5.615e-01, Loss_u: 3.995e-01, Loss_f: 1.620e-01
# Iter 700, Loss: 5.963e-01, Loss_u: 4.406e-01, Loss_f: 1.558e-01
# Iter 800, Loss: 3.487e-01, Loss_u: 1.890e-01, Loss_f: 1.597e-01
# Iter 900, Loss: 5.504e-01, Loss_u: 3.615e-01, Loss_f: 1.888e-01
# Iter 1000, Loss: 4.644e-01, Loss_u: 2.567e-01, Loss_f: 2.077e-01
# Iter 1100, Loss: 8.840e-01, Loss_u: 5.888e-01, Loss_f: 2.952e-01
# Iter 1200, Loss: 4.778e-01, Loss_u: 3.479e-01, Loss_f: 1.299e-01
# Iter 1300, Loss: 8.030e-01, Loss_u: 5.654e-01, Loss_f: 2.375e-01
# Iter 1400, Loss: 5.564e-01, Loss_u: 3.678e-01, Loss_f: 1.886e-01
# Iter 1500, Loss: 2.994e-01, Loss_u: 1.518e-01, Loss_f: 1.476e-01
# Iter 1600, Loss: 5.257e-01, Loss_u: 3.338e-01, Loss_f: 1.919e-01
# Iter 1700, Loss: 7.377e-01, Loss_u: 4.924e-01, Loss_f: 2.453e-01
# Iter 1800, Loss: 4.391e-01, Loss_u: 2.884e-01, Loss_f: 1.507e-01
# Iter 1900, Loss: 4.215e-01, Loss_u: 2.956e-01, Loss_f: 1.259e-01
# Total training data 100
# Total residual data 10100
# Iter 0, Loss: 2.253e+00, Loss_u: 2.227e+00, Loss_f: 2.549e-02
# Iter 100, Loss: 3.021e-01, Loss_u: 1.819e-01, Loss_f: 1.202e-01
# Iter 200, Loss: 2.006e-01, Loss_u: 7.379e-02, Loss_f: 1.268e-01
# Iter 300, Loss: 1.091e-01, Loss_u: 5.449e-02, Loss_f: 5.458e-02
# Iter 400, Loss: 1.208e-01, Loss_u: 6.111e-02, Loss_f: 5.970e-02
# Iter 500, Loss: 1.677e-01, Loss_u: 9.988e-02, Loss_f: 6.780e-02
# Iter 600, Loss: 1.821e-01, Loss_u: 8.731e-02, Loss_f: 9.481e-02
# Iter 700, Loss: 8.715e-02, Loss_u: 3.728e-02, Loss_f: 4.987e-02
# Iter 800, Loss: 5.979e-01, Loss_u: 4.194e-01, Loss_f: 1.785e-01
# Iter 900, Loss: 1.675e-01, Loss_u: 7.990e-02, Loss_f: 8.765e-02
# Iter 1000, Loss: 1.002e-01, Loss_u: 5.319e-02, Loss_f: 4.706e-02
# Iter 1100, Loss: 5.771e-01, Loss_u: 3.425e-01, Loss_f: 2.346e-01
# Iter 1200, Loss: 8.349e-02, Loss_u: 3.573e-02, Loss_f: 4.775e-02
# Iter 1300, Loss: 3.836e-01, Loss_u: 1.661e-01, Loss_f: 2.175e-01
# Iter 1400, Loss: 3.934e-02, Loss_u: 1.329e-02, Loss_f: 2.605e-02
# Iter 1500, Loss: 8.117e-02, Loss_u: 4.266e-02, Loss_f: 3.851e-02
# Iter 1600, Loss: 1.707e-01, Loss_u: 4.262e-02, Loss_f: 1.280e-01
# Iter 1700, Loss: 4.038e-01, Loss_u: 7.411e-02, Loss_f: 3.297e-01
# Iter 1800, Loss: 1.364e-01, Loss_u: 4.113e-02, Loss_f: 9.530e-02
# Iter 1900, Loss: 2.462e-01, Loss_u: 1.070e-01, Loss_f: 1.392e-01
