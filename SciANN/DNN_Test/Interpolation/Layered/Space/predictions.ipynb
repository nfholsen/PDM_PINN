# %%
# Notebook that will be used to compute the metrics used to select to best model.
# Input : model, first timestep and number of timestep to predict
# Output : csv file with ts, time, metrics, pictures of wavefields to save and receivers data

# %%
import sys

sys.path.append('C:/Users/nilso/Documents/EPFL/PDM/PDM_PINN/SciANN/DNN_TEST/sys/')

from loss import *
from unet import UNet
from dataloader import *
from BaseModel import BaseModel

import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

import h5py

import torch.optim as optim
import time
import json

# %%
class RecursivePredictions():
    def __init__(self,net,dataset):
        """
        net : pytorch model create with the BaseModel class
        dataset : torch dataset
        """

        self.net = net
        self.dataset = dataset

        self.net = self.net.to('cuda:0')

        #initial_test_sample,number_of_timestep_to_predict,timestep_to_plot)
    
    def predict_all(self,initial_timestep,number_of_timestep_to_predict,time_timestep,
                        timestep_to_plot:list,x_locations :list ,y_locations :list,dh:int):
        """
        initial_timestep : (int) first timestep to start the predictions
        number_of_timestep_to_predict : (int) number of timestep to do the predictions
        time_timestep : (float) time between two time steps 
        timestep_to_plot : (list) the timesteps to plot
        x_locations : (list)
        y_locations : (list)
        dh : (int)
        """
        start_time = time.time()

        # Wavefield to start the predictions
        initial_test_sample = self.dataset.__getitem__(initial_timestep)
        test_x = initial_test_sample['wave_input'].transpose(1, 0)[None]
        test_x = test_x.to('cpu')

        preds = np.zeros((len(timestep_to_plot),300,300))
        trues = np.zeros((len(timestep_to_plot),300,300))
        
        im = 0

        # Metrics 
        ts_vec = []
        time_vec = []
        norms = []
        receivers_pred = []
        receivers_true = []
        avg_abs_error_vec = []

        for ts in range(number_of_timestep_to_predict):

            epoch_start_time = time.time()
            
            test_x = test_x.to('cuda:0')

            # Prediciton for UNET
            test_gen = self.net(test_x).detach()

            pred = test_gen[0,0].cpu().numpy()

            # Ground truth wavefield
            test_gt = self.dataset.__getitem__(initial_timestep+ts)['wave_output'].transpose(1, 0)[None].detach()
            true = test_gt[0,0].cpu().numpy()

            # # # Store selected wavefield
            if ts in timestep_to_plot:

                print(f"Saving wavefield {ts}")
                preds[im,:,:] = test_gen[0,0].cpu().numpy()
                trues[im,:,:] = test_gt[0,0].cpu().numpy()
                im += 1

            # # # Compute metrics
            # Timestep 
            ts_vec.append(ts)

            # Time
            time_vec.append(ts * time_timestep)

            # Save norm
            norms.append(np.linalg.norm(true-pred))

            # Save receivers values
            receivers_pred.append(pred[(x_locations/dh).astype(int),(y_locations/dh).astype(int)])
            receivers_true.append(true[(x_locations/dh).astype(int),(y_locations/dh).astype(int)])
            
            # Average Absolute Error
            avg_abs_error = np.abs(np.subtract(true,pred)).mean()
            avg_abs_error_vec.append(avg_abs_error)

            # # # Update
            test_x = torch.cat((torch.cat((test_x[:,1:4,:,:],test_gen),dim=1),test_x[:,4:,:,:]),dim=1)
            #test_x = torch.cat((test_x,test_gen),dim=1)[:,1:,:,:]
 
            epoch_end_time = time.time()
            total_epoch_time = np.round(epoch_end_time - epoch_start_time, 2)
            print(f'\nTotal time for the timestep {ts} in seconds {total_epoch_time}')

        # # # Dict Metrics 
        dict_metrics = {'ts':ts_vec,'time':time_vec,'norms':norms,'receivers_pred':receivers_pred,'receivers_true':receivers_true,'avg_abs_error':avg_abs_error_vec}

        # # # Errors - preds, trues and errors will be used to print the wavefields
        errors = preds - trues

        # # # Time print
        end_time = time.time()
        total_time = end_time - start_time
        print(f'\nTotal time for the predictions [s] for {number_of_timestep_to_predict} timesteps :',np.round(total_time,2))

        return preds, trues, errors, dict_metrics

# %%
class Model(BaseModel):
    def __init__(self, net, opt=None, sched=None, logger=None, print_progress=True, device='cuda:0'):
        super().__init__(net, opt, sched, logger, print_progress, device)

    def forward_loss(self, data):
        return

# %%
# # # Data
event = 'Event0000'
velocity_field = '../../../Training_Data/Velocity_Field_2.npy'
training_data = dataset('../../../Training_Data/Moseley_EARTH_2/','../../../Training_Data/Moseley_EARTH_2.csv',event,velocity_field)

model_name = 'L2_GDL_MAE_E500'
model_type = 'unet'

net = UNet(in_channels=5,out_channels=1)

model = Model(net, device='cuda:0')
model.load(import_path=f'../{model_type}/results/{model_name}.pt',map_location='cuda:0')

predictions = RecursivePredictions(net=model.net,dataset=training_data)

# Load receivers data to obtain the coordinates
path = f"E:/PDM_SALVUS/NoCrack/Moseley_Homogeneous/{event}/receivers.h5"
hf = h5py.File(path, 'r')

# # # Parameters for the comparison
initial_timestep = 20
number_of_timestep_to_predict = 170 # max 170 : 170 + 20 (initial timestep) + 10 (first data)
time_timestep = 0.002
timestep_to_plot = [0,25,50,100,150]
x_locations = np.where(hf['coordinates_ACOUSTIC_point'][:] == 1500, 1495, hf['coordinates_ACOUSTIC_point'][:])[:,0]
y_locations = np.where(hf['coordinates_ACOUSTIC_point'][:] == 1500, 1495, hf['coordinates_ACOUSTIC_point'][:])[:,1]
dh = 5

# # # Names
results_name = f"{model_type}_" + model_name + ".csv"
errors_name = f"{model_type}_errors_" + model_name + ".npy"
preds_name = f"{model_type}_preds_" + model_name + ".npy"
trues_name = f"{model_type}_trues_" + model_name + ".npy"

save_path = results_name 

# # # Predictions
preds, trues, errors, dict_metrics = predictions.predict_all(initial_timestep=initial_timestep,number_of_timestep_to_predict=number_of_timestep_to_predict,time_timestep=time_timestep,timestep_to_plot=timestep_to_plot,x_locations=x_locations,y_locations=y_locations,dh=dh)

# # # Save
pd.DataFrame.from_dict(dict_metrics).to_csv(save_path)

for filename, object in zip([errors_name,trues_name,preds_name],[errors,trues,preds]):
    np.save(filename, object)
# Out:
# Saving wavefield 0
#
# Total time for the timestep 0 in seconds 0.11
#
# Total time for the timestep 1 in seconds 0.11
#
# Total time for the timestep 2 in seconds 0.11
#
# Total time for the timestep 3 in seconds 0.1
#
# Total time for the timestep 4 in seconds 0.11
#
# Total time for the timestep 5 in seconds 0.1
#
# Total time for the timestep 6 in seconds 0.11
#
# Total time for the timestep 7 in seconds 0.1
#
# Total time for the timestep 8 in seconds 0.11
#
# Total time for the timestep 9 in seconds 0.11
#
# Total time for the timestep 10 in seconds 0.11
#
# Total time for the timestep 11 in seconds 0.1
#
# Total time for the timestep 12 in seconds 0.11
#
# Total time for the timestep 13 in seconds 0.1
#
# Total time for the timestep 14 in seconds 0.11
#
# Total time for the timestep 15 in seconds 0.11
#
# Total time for the timestep 16 in seconds 0.11
#
# Total time for the timestep 17 in seconds 0.11
#
# Total time for the timestep 18 in seconds 0.1
#
# Total time for the timestep 19 in seconds 0.11
#
# Total time for the timestep 20 in seconds 0.1
#
# Total time for the timestep 21 in seconds 0.1
#
# Total time for the timestep 22 in seconds 0.11
#
# Total time for the timestep 23 in seconds 0.11
#
# Total time for the timestep 24 in seconds 0.11
# Saving wavefield 25
#
# Total time for the timestep 25 in seconds 0.11
#
# Total time for the timestep 26 in seconds 0.1
#
# Total time for the timestep 27 in seconds 0.11
#
# Total time for the timestep 28 in seconds 0.1
#
# Total time for the timestep 29 in seconds 0.11
#
# Total time for the timestep 30 in seconds 0.1
#
# Total time for the timestep 31 in seconds 0.11
#
# Total time for the timestep 32 in seconds 0.1
#
# Total time for the timestep 33 in seconds 0.11
#
# Total time for the timestep 34 in seconds 0.1
#
# Total time for the timestep 35 in seconds 0.1
#
# Total time for the timestep 36 in seconds 0.11
#
# Total time for the timestep 37 in seconds 0.11
#
# Total time for the timestep 38 in seconds 0.1
#
# Total time for the timestep 39 in seconds 0.1
#
# Total time for the timestep 40 in seconds 0.11
#
# Total time for the timestep 41 in seconds 0.11
#
# Total time for the timestep 42 in seconds 0.1
#
# Total time for the timestep 43 in seconds 0.11
#
# Total time for the timestep 44 in seconds 0.11
#
# Total time for the timestep 45 in seconds 0.11
#
# Total time for the timestep 46 in seconds 0.1
#
# Total time for the timestep 47 in seconds 0.1
#
# Total time for the timestep 48 in seconds 0.1
#
# Total time for the timestep 49 in seconds 0.1
# Saving wavefield 50
#
# Total time for the timestep 50 in seconds 0.1
#
# Total time for the timestep 51 in seconds 0.11
#
# Total time for the timestep 52 in seconds 0.11
#
# Total time for the timestep 53 in seconds 0.11
#
# Total time for the timestep 54 in seconds 0.11
#
# Total time for the timestep 55 in seconds 0.1
#
# Total time for the timestep 56 in seconds 0.11
#
# Total time for the timestep 57 in seconds 0.11
#
# Total time for the timestep 58 in seconds 0.11
#
# Total time for the timestep 59 in seconds 0.11
#
# Total time for the timestep 60 in seconds 0.11
#
# Total time for the timestep 61 in seconds 0.1
#
# Total time for the timestep 62 in seconds 0.11
#
# Total time for the timestep 63 in seconds 0.11
#
# Total time for the timestep 64 in seconds 0.1
#
# Total time for the timestep 65 in seconds 0.11
#
# Total time for the timestep 66 in seconds 0.1
#
# Total time for the timestep 67 in seconds 0.1
#
# Total time for the timestep 68 in seconds 0.11
#
# Total time for the timestep 69 in seconds 0.1
#
# Total time for the timestep 70 in seconds 0.1
#
# Total time for the timestep 71 in seconds 0.1
#
# Total time for the timestep 72 in seconds 0.11
#
# Total time for the timestep 73 in seconds 0.11
#
# Total time for the timestep 74 in seconds 0.1
#
# Total time for the timestep 75 in seconds 0.1
#
# Total time for the timestep 76 in seconds 0.11
#
# Total time for the timestep 77 in seconds 0.1
#
# Total time for the timestep 78 in seconds 0.1
#
# Total time for the timestep 79 in seconds 0.11
#
# Total time for the timestep 80 in seconds 0.11
#
# Total time for the timestep 81 in seconds 0.11
#
# Total time for the timestep 82 in seconds 0.11
#
# Total time for the timestep 83 in seconds 0.1
#
# Total time for the timestep 84 in seconds 0.1
#
# Total time for the timestep 85 in seconds 0.11
#
# Total time for the timestep 86 in seconds 0.1
#
# Total time for the timestep 87 in seconds 0.11
#
# Total time for the timestep 88 in seconds 0.1
#
# Total time for the timestep 89 in seconds 0.11
#
# Total time for the timestep 90 in seconds 0.1
#
# Total time for the timestep 91 in seconds 0.1
#
# Total time for the timestep 92 in seconds 0.11
#
# Total time for the timestep 93 in seconds 0.11
#
# Total time for the timestep 94 in seconds 0.11
#
# Total time for the timestep 95 in seconds 0.1
#
# Total time for the timestep 96 in seconds 0.11
#
# Total time for the timestep 97 in seconds 0.11
#
# Total time for the timestep 98 in seconds 0.1
#
# Total time for the timestep 99 in seconds 0.11
# Saving wavefield 100
#
# Total time for the timestep 100 in seconds 0.11
#
# Total time for the timestep 101 in seconds 0.11
#
# Total time for the timestep 102 in seconds 0.11
#
# Total time for the timestep 103 in seconds 0.11
#
# Total time for the timestep 104 in seconds 0.1
#
# Total time for the timestep 105 in seconds 0.11
#
# Total time for the timestep 106 in seconds 0.1
#
# Total time for the timestep 107 in seconds 0.11
#
# Total time for the timestep 108 in seconds 0.1
#
# Total time for the timestep 109 in seconds 0.11
#
# Total time for the timestep 110 in seconds 0.11
#
# Total time for the timestep 111 in seconds 0.11
#
# Total time for the timestep 112 in seconds 0.11
#
# Total time for the timestep 113 in seconds 0.11
#
# Total time for the timestep 114 in seconds 0.11
#
# Total time for the timestep 115 in seconds 0.1
#
# Total time for the timestep 116 in seconds 0.11
#
# Total time for the timestep 117 in seconds 0.11
#
# Total time for the timestep 118 in seconds 0.11
#
# Total time for the timestep 119 in seconds 0.11
#
# Total time for the timestep 120 in seconds 0.11
#
# Total time for the timestep 121 in seconds 0.11
#
# Total time for the timestep 122 in seconds 0.1
#
# Total time for the timestep 123 in seconds 0.1
#
# Total time for the timestep 124 in seconds 0.11
#
# Total time for the timestep 125 in seconds 0.11
#
# Total time for the timestep 126 in seconds 0.1
#
# Total time for the timestep 127 in seconds 0.11
#
# Total time for the timestep 128 in seconds 0.11
#
# Total time for the timestep 129 in seconds 0.11
#
# Total time for the timestep 130 in seconds 0.11
#
# Total time for the timestep 131 in seconds 0.11
#
# Total time for the timestep 132 in seconds 0.1
#
# Total time for the timestep 133 in seconds 0.11
#
# Total time for the timestep 134 in seconds 0.1
#
# Total time for the timestep 135 in seconds 0.11
#
# Total time for the timestep 136 in seconds 0.11
#
# Total time for the timestep 137 in seconds 0.11
#
# Total time for the timestep 138 in seconds 0.1
#
# Total time for the timestep 139 in seconds 0.11
#
# Total time for the timestep 140 in seconds 0.11
#
# Total time for the timestep 141 in seconds 0.11
#
# Total time for the timestep 142 in seconds 0.1
#
# Total time for the timestep 143 in seconds 0.1
#
# Total time for the timestep 144 in seconds 0.11
#
# Total time for the timestep 145 in seconds 0.11
#
# Total time for the timestep 146 in seconds 0.11
#
# Total time for the timestep 147 in seconds 0.11
#
# Total time for the timestep 148 in seconds 0.11
#
# Total time for the timestep 149 in seconds 0.1
# Saving wavefield 150
#
# Total time for the timestep 150 in seconds 0.11
#
# Total time for the timestep 151 in seconds 0.1
#
# Total time for the timestep 152 in seconds 0.1
#
# Total time for the timestep 153 in seconds 0.11
#
# Total time for the timestep 154 in seconds 0.1
#
# Total time for the timestep 155 in seconds 0.11
#
# Total time for the timestep 156 in seconds 0.1
#
# Total time for the timestep 157 in seconds 0.11
#
# Total time for the timestep 158 in seconds 0.1
#
# Total time for the timestep 159 in seconds 0.11
#
# Total time for the timestep 160 in seconds 0.1
#
# Total time for the timestep 161 in seconds 0.11
#
# Total time for the timestep 162 in seconds 0.11
#
# Total time for the timestep 163 in seconds 0.11
#
# Total time for the timestep 164 in seconds 0.11
#
# Total time for the timestep 165 in seconds 0.11
#
# Total time for the timestep 166 in seconds 0.11
#
# Total time for the timestep 167 in seconds 0.11
#
# Total time for the timestep 168 in seconds 0.11
#
# Total time for the timestep 169 in seconds 0.11
#
# Total time for the predictions [s] for 170 timesteps : 18.09
