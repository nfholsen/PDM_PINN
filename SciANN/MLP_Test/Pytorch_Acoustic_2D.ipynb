# %% [markdown]
# Classical approach https://www.youtube.com/watch?v=uJHcULXF1HE

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

import h5py

# %%
path = "NoCracK/Simple_Homogeneous/Event0000/output.h5"

hf = h5py.File(path, 'r')

# %%
selected_ts = 50
t_s = 1e-7

loc = hf['coordinates_ACOUSTIC'][:].reshape(hf['coordinates_ACOUSTIC'][:].shape[0]*hf['coordinates_ACOUSTIC'][:].shape[1],2)

df = pd.DataFrame(columns={'X','Y'})
df['X'] = loc[:,0]
df['Y'] = loc[:,1]
df['X'] = np.round(df['X'],5)
df['Y'] = np.round(df['Y'],5)

values = hf['volume']['phi'][selected_ts,:,:,:25].reshape(2500*25)

df['PHI'] = values
df['T'] = selected_ts * t_s

df_clean = df.loc[::25].pivot_table(values='PHI',index='Y',columns='X')
df_clean.sort_index(axis=0,ascending=False,inplace=True)

# %%
df_train_tot = df.loc[::25]

# %%
plt.imshow(df_clean.values)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import time

# %%
class PINN(nn.Module):
    def __init__(self,
                in_size = 3, 
                neurons_layer=[32, 32, 32, 32],
                out_size = 1
                ):
        """
        Initializing the PINN
        """
        nn.Module.__init__(self)

        self.layers = nn.ModuleList()
        
        self.layers.append(nn.Linear(in_features=in_size, out_features=neurons_layer[0]))
        for n_in, n_out in zip(neurons_layer[:-1], neurons_layer[1:]):
            self.layers.append(nn.Linear(in_features=n_in, out_features=n_out))
        self.out  = nn.Linear(in_features=neurons_layer[-1], out_features=out_size)
        
        self.relu = nn.ReLU()

    def forward(self, x):
        """
        Forward Pass
        """
        for linear in self.layers:
            x = self.relu(linear(x))
        x = self.out(x)
        return x


class PINN_loss(nn.Module):
    def __init__(self, device=None):
        """
        device : self explenatory, cuda if possible 
        """

        nn.Module.__init__(self)

        self.device = device

    def forward(self,p,p_true,x,y,t,c):

        # # # Compute derivatives
        p.requires_grad_(True)

        p_t = torch.sum(self.get_gradient(p, t), dim= 1)
        p_x = torch.sum(self.get_gradient(p, x), dim= 1)
        p_y = torch.sum(self.get_gradient(p, y), dim= 1)

        p_t.requires_grad_(True)
        p_x.requires_grad_(True)
        p_y.requires_grad_(True)

        p_tt = torch.sum(self.get_gradient(p_t, t), dim= 1)
        p_xx = torch.sum(self.get_gradient(p_x, x), dim= 1)
        p_yy = torch.sum(self.get_gradient(p_y, y), dim= 1)

        # # # Wave acoustic equation
        r_p = p_xx + p_yy - 1/(c ** 2) * p_tt 

        # # # Compute loss
        error = torch.mean(torch.square(p - p_true))
        regul = torch.mean(torch.square(r_p))

        print('error',error)
        print('regul',regul)

        return error + regul

    def get_gradient(self, f, x):
        """ computes gradient of tensor f with respect to tensor x """
        assert x.requires_grad_

        x_shape = x.shape
        f_shape = f.shape
        f = f.view(-1)

        x_grads = []
        for f_val in f:
            if x.grad is not None:
                x.grad.data.zero_()
            f_val.backward(retain_graph=True)
            if x.grad is not None:
                x_grads.append(deepcopy(x.grad.data))
            else:
                # in case f isn't a function of x
                x_grads.append(torch.zeros(x.shape).to(x))
        output_shape = list(f_shape) + list(x_shape)
        return torch.cat((x_grads)).view(output_shape)

# %%
class Net():
    """
    Net for Acoustic Wave Propagation
    """
    def __init__(self, model, loss, data_train, data_test):
        
        self.x = data_train['x']
        self.y = data_train['y']
        self.t = data_train['t']
        self.p_true = data_train['p_true']

        self.model = model
        self.loss = loss
    def train(self):
        X = torch.stack((self.x, self.y, self.t), 1)

        p = self.model(X)

# %%
data_max = df_train_tot.shape[0]

# %%
idx = np.random.randint(0,data_max,size=1000)

# %%
df_train_tot = df_train_tot.reset_index(drop=True)

# %%
df_train = df_train_tot.loc[idx,:].reset_index(drop=True)

# %%
class PINNDataset(Dataset):
    def __init__(self, df):
        super(Dataset, self).__init__()

        self.df = df

    def __len__(self):
        return self.df.shape[0]
        
    def __getitem__(self, index):

        # X 
        x = torch.tensor(self.df.loc[index,'X']).float()
        y = torch.tensor(self.df.loc[index,'Y']).float()
        t = torch.tensor(self.df.loc[index,'T']).float()

        # Y
        p = self.df.loc[index,'PHI']

        return x, y, t, p

# %%
df_train
# Out:
#          X      Y           PHI         T
# 0    0.060  0.175 -1.952819e-20  0.000005
# 1    0.155  0.175  1.331143e-08  0.000005
# 2    0.145  0.195 -1.429638e-12  0.000005
# 3    0.060  0.060  2.851429e-25  0.000005
# 4    0.030  0.240  0.000000e+00  0.000005
# ..     ...    ...           ...       ...
# 995  0.060  0.220  0.000000e+00  0.000005
# 996  0.020  0.080 -3.034643e-34  0.000005
# 997  0.200  0.245  0.000000e+00  0.000005
# 998  0.065  0.185  1.387116e-21  0.000005
# 999  0.120  0.140 -3.043203e+00  0.000005
#
# [1000 rows x 4 columns]

# %%
plt.scatter(df_train['X'].values,df_train['Y'].values,c=df_train['PHI'].values)

# %%
epoch = 2

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Initialize the model
PINN_net = PINN() 
PINN_net = PINN_net.to(device)
# Prepare the dataset
train_dataset = PINNDataset(df_train)
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)

# Define the loss function and optimizer
LOSS_net = PINN_loss()
optimizer = torch.optim.Adam(PINN_net.parameters(), lr=1e-4)

t0 = time.time()

for i in range(epoch):

    # Set loss value
    current_loss = 0.0

    # Iterate over training data for every mini batch
    for x,y,t, p_true in trainloader:

        # Concatenate data
        X = torch.stack((x, y, t),1)

        X = X.to(device)
        X.require_grad = True
        p_true = p_true.to(device)

        optimizer.zero_grad() # Zero the gradients

        # Forward
        p_train = PINN_net(X) # Perform forward pass
        loss = LOSS_net(p_train,p_true,x,y,t,c=1) # Compute loss

        # Backward and optimize 
        loss.backward() # Perform backward pass
        optimizer.step() # Perform optimization

        current_loss += loss.item()

    t1 = time.time()
    ### Training status
    print('Epoch %d, Loss= %.10f, Time= %.4f' % (i, current_loss, t1-t0))
# Out:
# tensor(0.)
# error tensor(49.0974, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1828, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.7298, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.5420, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(75.8675, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.9618, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0433, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.3185, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.4687, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(102.5747, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0453, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1492, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0461, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0467, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(21.1616, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(33.0242, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0492, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(41.3308, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.7343, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(108.0254, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0515, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.4241, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.2370, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3286, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(76.7977, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(48.8052, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(90.5980, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.6087, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.9122, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.0233, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(12.4561, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(83.2545, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(28.0970, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.9313, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(12.5216, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.5303, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0721, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.1059, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0649, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.0864, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(25.7097, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.6207, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.8632, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2810, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(83.6674, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.6418, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0717, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.8864, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(29.4536, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(63.0612, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.4357, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.7351, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.0776, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(53.2986, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.7507, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(71.4292, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.6887, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(63.5241, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(71.3522, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(8.9375, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.0165, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(10.7635, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(24.7829, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.1927, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1499, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.6418, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(84.8028, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(25.7773, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(12.3785, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.9040, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.9857, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(60.3644, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.6280, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(13.6718, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6220, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.5366, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(39.1560, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1085, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.2244, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1087, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(42.6841, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.3610, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(45.3828, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.1835, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1778, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(67.8457, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(134.8618, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(18.9390, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(36.0625, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.1284, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# Epoch 0, Loss= 4249.4005846530, Time= 3072.8843
# error tensor(5.7696, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(55.5039, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(11.5908, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.8108, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(64.4033, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.6659, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.7718, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(25.8845, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.5988, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(10.0476, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.7150, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(8.8311, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.0659, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(8.0451, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(18.4674, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.7067, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(73.7169, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.4402, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.6214, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.8660, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(48.1594, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.5825, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(61.8548, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.1637, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.6776, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(76.9642, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(106.2916, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(15.4889, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.9687, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.5449, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.9489, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.2928, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.5754, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(80.3729, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(38.5730, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2045, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2648, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.2242, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(52.2910, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(68.3008, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2774, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(19.2310, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(66.1157, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(138.8860, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2385, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.3824, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.9120, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(30.9897, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.1364, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(21.0032, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2529, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(46.1582, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2666, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(42.2359, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.9862, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(64.4147, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.0153, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(13.4126, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.3673, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6133, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.2981, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3106, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.9317, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3147, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.9302, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(65.8329, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.9880, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(25.6025, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3382, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(49.5223, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.8662, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3521, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(103.4598, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(58.8585, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.6259, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3729, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.5470, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.3776, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(12.1980, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.4094, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(22.1909, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.4063, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(43.6364, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(84.7071, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(73.0673, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(27.6334, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(63.1955, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.6247, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(77.4266, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(17.6086, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(8.2320, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.2587, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(5.2643, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.9814, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(80.6892, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(65.9079, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.5321, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(32.8313, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.8064, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(80.9255, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(15.4658, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.9684, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(75.6213, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.0653, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(52.3564, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(13.1309, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(2.1476, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(22.0070, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6360, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.6500, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6088, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6230, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(14.1827, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(28.0003, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6521, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(63.2202, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(59.8088, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.0223, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.7893, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.6961, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.7156, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(58.6188, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(85.5019, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(58.2557, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(84.0603, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(35.2302, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(75.2684, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(0.7811, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(12.8515, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(15.3811, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(181.8344, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(105.0890, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.3505, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(71.7361, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(51.6311, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(169.2938, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.1838, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(71.7916, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.4845, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(43.7195, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(13.2149, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(7.8999, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(4.7543, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(54.3339, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.7251, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(15.3002, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(3.8611, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.1839, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(62.7481, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(20.4656, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(1.3990, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.0631, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(9.6381, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(6.0555, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(17.6180, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(109.7179, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# error tensor(16.9579, device='cuda:0', grad_fn=<MeanBackward0>)
# regul tensor(0.)
# Epoch 1, Loss= 4375.5924839973, Time= 6023.9088

# %%
# Validation Set
x = torch.tensor(df_train_tot.loc[:,'X']).float()
y = torch.tensor(df_train_tot.loc[:,'Y']).float()
t = torch.tensor(df_train_tot.loc[:,'T']).float()

X = torch.stack((x, y, t),1)

X = X.to(device)

# %%
p_preds = PINN_net(X)

# %%
df_train_tot['p_pred'] = p_preds.cpu().detach().numpy()

# %%
df_preds = df_train_tot.pivot_table(values='p_pred',index='Y',columns='X')
df_preds.sort_index(axis=0,ascending=False,inplace=True)

# %%
plt.imshow(df_preds.values)
plt.colorbar()
