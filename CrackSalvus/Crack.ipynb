# %%
# Standard Python packages
import toml
import math
from pathlib import Path
import json
import h5py

import random

# Workflow management.
from salvus.flow import api

# Specific objects to aid in setting up simulations.
import salvus.flow.simple_config as sc

import sys
sys.path.append('/home/nolsen/Salvus/Salvus_PDM/CrackSalvus/Helpers/')

from helpers import *
from my_crack import *

# %%
# Opening JSON file 
f = open('config_file.json',) 
inputs = json.load(f) 
f.close()

# %%
nelem_x=inputs['mesh']['nelem_x']
nelem_y=inputs['mesh']['nelem_y']
min_x = inputs['mesh']['x_min']
max_x = inputs['mesh']['x_max']
min_y = inputs['mesh']['y_min']
max_y = inputs['mesh']['y_max']

a = inputs['fracture'][0]['parameters']['a']
b = inputs['fracture'][0]['parameters']['b']
x_center = inputs['fracture'][0]['parameters']['x_center']
y_center = inputs['fracture'][0]['parameters']['y_center']

type = 'crack'

experiment_name = 'Spherical_Crack'

output_folder = inputs['simulation']['output_path'] + "/" + experiment_name

# %%
# Create unstructured_mesh 
mesh = get_mesh(nelem_x=nelem_x, nelem_y=nelem_y, max_x=max_x, max_y=max_y)

# Create Crack
crack_obj = MyEllipticalCrack(nelem_x=nelem_x,
                            nelem_y=nelem_y,
                            max_x=max_x,
                            max_y=max_y,
                            a=a,
                            b=b,
                            x_center=x_center,
                            y_center=y_center)

# %%
np.random.seed(12345) # Fix seed for earth models
random.seed(12345)

# # # Create the mesh object
mesh_obj = Mesh(mesh,inputs['materials'][0])

# # # Assign the correct type of material and geometry to the mesh

if type == 'crack' : # Fracture 
    final_mesh, dict_materials = mesh_obj.add_crack(crack_obj,inputs['materials'])

elif type == 'earth' : # Earth realistic model
    number_of_separation = np.random.randint(1,5)

    # Create separation for layers
    layers_y = [min_y]
    layers_y += [i for i in np.sort(random.sample(range(min_y+50,max_y-50,50),number_of_separation))]
    layers_y += [max_y]

    vp = np.random.choice(np.array(range(2000,2800,100)),size=number_of_separation+1,replace=False)
    rho = rho_from_gardeners(vp)

    x = np.linspace(0, max_x, nelem_x)
    y = np.linspace(max_y, 0, nelem_y)
    yy, xx = np.meshgrid(y, x, indexing="ij")

    regions = np.zeros((nelem_y,nelem_x))

    for i in range(len(layers_y)-1):

        index = np.argsort(vp)[::-1][i]

        regions[(yy >= layers_y[index]) & (yy <= layers_y[index+1])] = i

    mesh_obj.mesh.elemental_fields["region"] = regions.ravel()

    index_vp = np.argsort(vp)[::-1]

    mesh_obj.add_layers(index_vp,vp,rho)

    final_mesh = mesh_obj.attach_materials()
    dict_materials = {'VP':mesh_obj.vpa,'RHO':mesh_obj.rhoa}


elif type == 'homogeneous' : # Homogeneous
    final_mesh = mesh_obj.attach_materials()
    dict_materials = {'VP':mesh_obj.vpa,'RHO':mesh_obj.rhoa}

else :
    raise TypeError("Not the correct model type was assigned, possible types are 'crack', 'earth' and 'homogeneous'")


# # # Sources
srcs = [
    sc.source.cartesian.ScalarPoint2D(
            x=src['location']['x'],
            y=src['location']['y'],
            f=src['location']['fx'], 
            source_time_function=sc.stf.Ricker(center_frequency=src['frequency']))
         for _i, src in enumerate(inputs['sources'])   
]

# # # Receivers
recs = [
    sc.receiver.cartesian.Point2D(
        x=rec['location']['x'], 
        y=rec['location']['y'], 
        station_code=f"{_i:03d}", 
        fields=[rec['field']])
    for _i, rec in enumerate(inputs['receivers'])
]

# %%
import matplotlib as mpl
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Plot geometry of the problem - Sanity check 
fig, ax = plt.subplots(1,3,figsize=(12,6))

ax = ax.ravel()

ax[0].plot([min_x,max_x,max_x,min_x,min_x],[min_y,min_y,max_y,max_y,min_y])

# Plot receivers - in black below
for i in range(len(recs)):
    ax[0].scatter(
    recs[i].get_dictionary()['location'][0],recs[i].get_dictionary()['location'][1], c='k'
)
# Plot sources - in red below
for i in range(len(srcs)):
    ax[0].scatter(
    srcs[i].get_dictionary()['location'][0],srcs[i].get_dictionary()['location'][1], c ='r'
)

ax[0].set_aspect('equal')
ax[0].set_position([0,0.31,0.45,0.45])
ax[0].set_xticks(range(0, max_x+500, 500))
ax[0].set_yticks(range(0, max_y+500, 500))

for (_i, (name, data)), col, label in zip(enumerate(dict_materials.items()),[vp,rho],['VP values $[m/s]$','RHO values $[kg/m^3]$']):

    _i = _i + 1

    norm = colors.Normalize(vmin=col.min(), vmax=col.max())
    cmap = mpl.colors.ListedColormap(mpl.cm.viridis(norm(np.sort(col)[::-1]),bytes=True)/255)

    im = ax[_i].imshow(regions, cmap=cmap,extent=[min_x,max_x,min_y,max_y])
    ax[_i].set_aspect('equal')
    ax[_i].set_xticks(range(0, max_x+500, 500))
    ax[_i].set_yticks(range(0, max_y+500, 500))

    divider = make_axes_locatable(ax[_i])
    cax = divider.append_axes("bottom", size="5%", pad=0.3)

    cbar = plt.colorbar(im, cax=cax,label=label,orientation="horizontal")

    tick_locs = (np.arange(len(col)) + 0.5)*(len(col)-1)/len(col)
    cbar.set_ticks(tick_locs)
    cbar.set_ticklabels(np.sort(col)[::-1].astype(int))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-96444f32429d> in <module>
#      19 ax[0].set_aspect('equal')
#      20 ax[0].set_position([0,0.31,0.45,0.45])
# ---> 21 ax[0].set_xticks(range(0, max_x+500, 500))
#      22 ax[0].set_yticks(range(0, max_y+500, 500))
#      23
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
plot_setup(0.25,srcs,recs)

# %%
output_folder
# Out:
# 'ForwardOutput/Crack/Spherical_Crack'

# %%
salvus_sim = SalvusSimulation(mesh=mesh, srcs=srcs, recs=recs, output_folder=output_folder)

# %%
salvus_sim.run(start_time=inputs['simulation']['start_time'],
        end_time=inputs['simulation']['end_time'],
        time_step=inputs['simulation']['end_time']/10000,
        wavefield_sampling=10)
# Out:
# EVENT0000
# Job `job_2105111135622132_0733098ea9` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0000`.
# * Total run time: 6.78 seconds.
# * Pure simulation time: 5.98 seconds.
#
# EVENT0001
# Job `job_2105111135820411_7777aa7e8c` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0001`.
# * Total run time: 7.73 seconds.
# * Pure simulation time: 6.94 seconds.
#
# EVENT0002
# Job `job_2105111136964151_e560d657d3` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0002`.
# * Total run time: 8.79 seconds.
# * Pure simulation time: 8.06 seconds.
#
# EVENT0003
# Job `job_2105111136311640_b380fe1aa6` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0003`.
# * Total run time: 8.16 seconds.
# * Pure simulation time: 6.95 seconds.
#
# EVENT0004
# Job `job_2105111136935803_505426e609` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0004`.
# * Total run time: 11.79 seconds.
# * Pure simulation time: 11.00 seconds.
#
# EVENT0005
# Job `job_2105111136134628_ad3a687198` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0005`.
# * Total run time: 10.41 seconds.
# * Pure simulation time: 9.08 seconds.
#
# EVENT0006
# Job `job_2105111136118599_ab1b9cd914` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0006`.
# * Total run time: 10.67 seconds.
# * Pure simulation time: 9.78 seconds.
#
# EVENT0007
# Job `job_2105111137867065_64a930b377` running on `local` with 4 rank(s).
# Site information:
#   * Salvus version: 0.11.31
#   * Floating point size: 32
# Solving forward problem/Computing forward wavefield:   0%|          | 0/10000 [00:00<?, ?it/s]
# * Downloaded 308.7 MB of results to `ForwardOutput/Crack/Spherical_Crack/EVENT0007`.
# * Total run time: 13.10 seconds.
# * Pure simulation time: 11.51 seconds.

# %%
filename = "ForwardOutput/Crack/Spherical_Crack/EVENT0000/output.h5"
hf = h5py.File(filename, 'r')
number_of_ts = hf['volume'].get('phi').shape[0]

print('NUMBER OF TS',number_of_ts)
# Out:
# NUMBER OF TS 1001

# %% [markdown]
# ## Plot receivers data

# %%
def get_plot(hf,selected_time_step):
    """
    INPUT : HF (output.h5)
    """

    df_loc = pd.DataFrame()
    df_loc['X'] = hf['coordinates_ACOUSTIC'][:,0][:,0].astype(float)
    df_loc['Y'] = hf['coordinates_ACOUSTIC'][:,0][:,1].astype(float)
    df_loc['PHI'] = hf['volume']['phi'][selected_time_step][:,0].mean(axis=1)

    # Pivot to have to optain numpy array 
    df_clean = df_loc.pivot_table(values='PHI', index='Y', columns='X')

    df_clean.sort_index(axis=0 ,ascending=False,inplace=True)
    return df_clean

# %%
selected_time_step  = 100 # Number between 0 and number_of_ts

selected_event = 0

# %%
filename = "ForwardOutput/Crack/Spherical_Crack/EVENT{0:04}/receivers.h5".format(selected_event)
hf = h5py.File(filename, 'r')

filename = "ForwardOutput/Crack/Spherical_Crack/EVENT{0:04}/output.h5".format(selected_event)
hf_plot = h5py.File(filename, 'r')

# %%
number_of_ts = hf_plot['volume'].get('phi').shape[0]
list_of_timestep = list(np.arange(0,np.asarray(hf['point']['phi']).shape[2],10)) + [np.asarray(hf['point']['phi']).shape[2]] # 10 is for the timestep volume_data interval

df_clean = get_plot(hf_plot,selected_time_step)

fig = plt.figure(figsize=(20,10))
gs = fig.add_gridspec(8,3,width_ratios=[0.7,4,6])


for _i in range(8): 
    ax = fig.add_subplot(gs[_i, 0])
    ax.plot([0,0.25,0.25,0,0],[0,0,0.25,0.25,0])
    ax.set_xlim(-0.05,0.3)
    ax.set_ylim(-0.05,0.3)

    ax.scatter(np.asarray(hf['coordinates_ACOUSTIC_point'])[_i,0],np.asarray(hf['coordinates_ACOUSTIC_point'])[_i,1],c='k')
    ax.scatter(srcs[selected_event].get_dictionary()['location'][0],srcs[selected_event].get_dictionary()['location'][1],c='r')
    
    ax.set_aspect('equal', 'box')
    ax.axis('off')

    ax = fig.add_subplot(gs[_i, 1])
    value_max = hf['point'].get('phi')[:][_i,0,:].max()
    value_min = hf['point'].get('phi')[:][_i,0,:].min()

    ax.fill_between([selected_time_step*10-10,selected_time_step*10+10],[value_max,value_max],[value_min,value_min])
    ax.plot(np.array(hf['point'].get('phi'))[_i,0,:])
    ax.set_xlim(0,hf['point'].get('phi')[:].shape[2])

    if _i < 7:
        ax.tick_params(
        axis='x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False)

ax = fig.add_subplot(gs[:, 2])
ax.imshow(df_clean.values,extent=[0,0.25,0,0.25])
ax.set_aspect('equal', 'box')

plt.gcf().text(0.127, 0.9, 'Schema', fontsize=14)
plt.gcf().text(0.28, 0.9, 'Data at the receiver', fontsize=14)
plt.gcf().text(0.62, 0.9, f'Wavefield snapsot at timestep = {selected_time_step}', fontsize=14)
# Out:
# Text(0.62, 0.9, 'Wavefield snapsot at timestep = 100')
